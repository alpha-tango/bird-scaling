# %%
import duckdb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm

# %% [markdown]
# ### Distinct Species as a Function of Time

# %%
sql = """
SELECT
    make_date(extract('year' FROM CAST(observation_date AS date)), extract('month' FROM CAST(observation_date AS date)), 1) AS observation_date,
    COUNT(DISTINCT scientific_name) AS species_count
FROM read_parquet([
    'data/ebird_2015.parquet',
    'data/ebird_2016.parquet',
    'data/ebird_2017.parquet',
    'data/ebird_2018.parquet',
    'data/ebird_2019.parquet',
    'data/ebird_2020.parquet',
    'data/ebird_2021.parquet',
    'data/ebird_2022.parquet'])
GROUP BY 1
ORDER BY 1
"""
results = duckdb.sql(sql)

# %%
results_df = results.df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
results_df
# Out:
#    observation_date  species_count
# 0        2015-01-01            990
# 1        2015-02-01            981
# 2        2015-03-01           1045
# 3        2015-04-01           1096
# 4        2015-05-01           1139
# ..              ...            ...
# 91       2022-08-01           1192
# 92       2022-09-01           1205
# 93       2022-10-01           1209
# 94       2022-11-01           1122
# 95       2022-12-01           1105
#
# [96 rows x 2 columns]

# %%
fig, ax = plt.subplots()
ax.plot(results_df['observation_date'], results_df['species_count'])

# %%
sql = """
SELECT
    make_date(extract('year' FROM CAST(observation_date AS date)), 7, 1) AS observation_year,
    COUNT(DISTINCT scientific_name) AS species_count
FROM read_parquet([
    'data/ebird_2015.parquet',
    'data/ebird_2016.parquet',
    'data/ebird_2017.parquet',
    'data/ebird_2018.parquet',
    'data/ebird_2019.parquet',
    'data/ebird_2020.parquet',
    'data/ebird_2021.parquet',
    'data/ebird_2022.parquet'])
GROUP BY 1
ORDER BY 1
"""
results = duckdb.sql(sql)
year_results = results.df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
year_results
# Out:
#   observation_year  species_count
# 0       2015-07-01           1453
# 1       2016-07-01           1452
# 2       2017-07-01           1481
# 3       2018-07-01           1491
# 4       2019-07-01           1490
# 5       2020-07-01           1495
# 6       2021-07-01           1528
# 7       2022-07-01           1555

# %%
fig, ax = plt.subplots()
ax.plot(results_df['observation_date'], results_df['species_count'], label='Monthly Distinct Species')
ax.plot(year_results['observation_year'], year_results['species_count'], label='Yearly Distinct Species')
ax.set_ylim(0, 1700)
ax.legend()
ax.set_title("Distinct Species Observed over Time (USA States)")
# Out:
# Text(0.5, 1.0, 'Distinct Species Observed over Time (USA States)')

# %% [markdown]
# ### Birder Counts

# %%
sql = """
SELECT
    make_date(extract('year' FROM CAST(observation_date AS date)), extract('month' FROM CAST(observation_date AS date)), 1) AS observation_date,
    COUNT(DISTINCT observer_id) AS observer_count
FROM read_parquet([
    'data/ebird_2015.parquet',
    'data/ebird_2016.parquet',
    'data/ebird_2017.parquet',
    'data/ebird_2018.parquet',
    'data/ebird_2019.parquet',
    'data/ebird_2020.parquet',
    'data/ebird_2021.parquet',
    'data/ebird_2022.parquet'])
GROUP BY 1
ORDER BY 1
"""
results = duckdb.sql(sql)
birder_results = results.df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
sql = """
SELECT
    make_date(extract('year' FROM CAST(observation_date AS date)), 7, 1) AS observation_year,
    COUNT(DISTINCT observer_id) AS observer_count
FROM read_parquet([
    'data/ebird_2015.parquet',
    'data/ebird_2016.parquet',
    'data/ebird_2017.parquet',
    'data/ebird_2018.parquet',
    'data/ebird_2019.parquet',
    'data/ebird_2020.parquet',
    'data/ebird_2021.parquet',
    'data/ebird_2022.parquet'])
GROUP BY 1
ORDER BY 1
"""
results = duckdb.sql(sql)
year_birder_results = results.df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
fig, ax = plt.subplots()
ax.plot(birder_results['observation_date'], birder_results['observer_count'], label="Monthly Distinct Birders")
ax.plot(year_birder_results['observation_year'], year_birder_results['observer_count'], label="Yearly Distinct Birders")
ax.set_ylim(0, 200000)
ax.legend()
ax.set_title("Distinct Birders over Time (USA States)")
# Out:
# Text(0.5, 1.0, 'Distinct Birders over Time (USA States)')

# %%
sql = """
SELECT
        observer_id,
        COUNT(DISTINCT CAST(observation_date AS date)) AS distinct_days_observing
FROM 'data/ebird_2022.parquet'
GROUP BY 1
"""
results = duckdb.sql(sql)
birder_frequency_results = results.df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
birder_frequency_results.tail()
# Out:
#         OBSERVER_ID  distinct_days_observing
# 172305  obsr2167135                        1
# 172306  obsr1144121                        1
# 172307  obsr3067738                        1
# 172308  obsr2187447                        1
# 172309  obsr2328920                        1

# %%
fig, ax = plt.subplots()
ax.hist(birder_frequency_results['distinct_days_observing'])
ax.axvline(birder_frequency_results['distinct_days_observing'].median(), color='black', linewidth=2, label='Median')
ax.axvline(birder_frequency_results['distinct_days_observing'].mean(), linestyle='dashed', color='black', linewidth=2, label='Mean')

ax.set_yscale('log')
ax.set_xlabel("Number of Days Observations Made")
ax.set_ylabel("Count of Birders (Log10 Scale)")
ax.legend()
ax.set_title("2022 Birder Count by Days Observing")
# Out:
# Text(0.5, 1.0, '2022 Birder Count by Days Observing')

# %% [markdown]
# ### Duration Minutes

# %%
sql = """
SELECT
        observer_id,
        observation_date,
        common_name,
        scientific_name,
        duration_minutes,
        observation_count,
        time_observations_started,
        sampling_event_identifier,
        protocol_type,
        protocol_code
FROM 'data/ebird_2022.parquet'
WHERE observer_id = 'obsr95380'
AND observation_date = '2022-11-25'
ORDER BY DURATION_MINUTES DESC

LIMIT 100
"""
results = duckdb.sql(sql)
test = results.df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
pd.set_option('display.max_rows', 100)
test
# Out:
#    OBSERVER_ID OBSERVATION_DATE               COMMON_NAME  \
# 0    obsr95380       2022-11-25         Northern Cardinal
# 1    obsr95380       2022-11-25                  Ovenbird
# 2    obsr95380       2022-11-25                  Blue Jay
# 3    obsr95380       2022-11-25            Eastern Phoebe
# 4    obsr95380       2022-11-25                Bald Eagle
# 5    obsr95380       2022-11-25                House Wren
# 6    obsr95380       2022-11-25          Chipping Sparrow
# 7    obsr95380       2022-11-25          White-eyed Vireo
# 8    obsr95380       2022-11-25           Tufted Titmouse
# 9    obsr95380       2022-11-25               Wild Turkey
# 10   obsr95380       2022-11-25     Blue-gray Gnatcatcher
# 11   obsr95380       2022-11-25       Boat-tailed Grackle
# 12   obsr95380       2022-11-25               Green Heron
# 13   obsr95380       2022-11-25        Eastern Meadowlark
# 14   obsr95380       2022-11-25         Blue-headed Vireo
# 15   obsr95380       2022-11-25            Sandhill Crane
# 16   obsr95380       2022-11-25     Yellow-rumped Warbler
# 17   obsr95380       2022-11-25          Downy Woodpecker
# 18   obsr95380       2022-11-25   Yellow-throated Warbler
# 19   obsr95380       2022-11-25     Yellow-rumped Warbler
# 20   obsr95380       2022-11-25      Northern Mockingbird
# 21   obsr95380       2022-11-25       Pileated Woodpecker
# 22   obsr95380       2022-11-25               Great Egret
# 23   obsr95380       2022-11-25    Red-bellied Woodpecker
# 24   obsr95380       2022-11-25          Northern Flicker
# 25   obsr95380       2022-11-25              Gray Catbird
# 26   obsr95380       2022-11-25              Palm Warbler
# 27   obsr95380       2022-11-25                 Fish Crow
# 28   obsr95380       2022-11-25                Wood Stork
# 29   obsr95380       2022-11-25            Common Grackle
# 30   obsr95380       2022-11-25       Common Yellowthroat
# 31   obsr95380       2022-11-25      Ruby-crowned Kinglet
# 32   obsr95380       2022-11-25                  Killdeer
# 33   obsr95380       2022-11-25            American Robin
# 34   obsr95380       2022-11-25             Black Vulture
# 35   obsr95380       2022-11-25        Common Ground Dove
# 36   obsr95380       2022-11-25   Black-and-white Warbler
# 37   obsr95380       2022-11-25       Red-shouldered Hawk
# 38   obsr95380       2022-11-25             American Crow
# 39   obsr95380       2022-11-25              Palm Warbler
# 40   obsr95380       2022-11-25         Little Blue Heron
# 41   obsr95380       2022-11-25              Pine Warbler
# 42   obsr95380       2022-11-25         American Redstart
# 43   obsr95380       2022-11-25              Palm Warbler
# 44   obsr95380       2022-11-25             Mourning Dove
# 45   obsr95380       2022-11-25  Yellow-bellied Sapsucker
# 46   obsr95380       2022-11-25         Loggerhead Shrike
# 47   obsr95380       2022-11-25            Turkey Vulture
# 48   obsr95380       2022-11-25          White-eyed Vireo
# 49   obsr95380       2022-11-25            American Robin
# 50   obsr95380       2022-11-25         American Redstart
# 51   obsr95380       2022-11-25    Red-bellied Woodpecker
# 52   obsr95380       2022-11-25     Yellow-rumped Warbler
# 53   obsr95380       2022-11-25             Hermit Thrush
# 54   obsr95380       2022-11-25            Sandhill Crane
# 55   obsr95380       2022-11-25   Black-and-white Warbler
# 56   obsr95380       2022-11-25                House Wren
# 57   obsr95380       2022-11-25           Prairie Warbler
# 58   obsr95380       2022-11-25          Downy Woodpecker
# 59   obsr95380       2022-11-25              Gray Catbird
# 60   obsr95380       2022-11-25                  Ovenbird
# 61   obsr95380       2022-11-25            Eastern Phoebe
# 62   obsr95380       2022-11-25   Yellow-throated Warbler
# 63   obsr95380       2022-11-25             Carolina Wren
# 64   obsr95380       2022-11-25     Blue-gray Gnatcatcher
# 65   obsr95380       2022-11-25                  Blue Jay
# 66   obsr95380       2022-11-25         Blue-headed Vireo
# 67   obsr95380       2022-11-25         Northern Cardinal
# 68   obsr95380       2022-11-25       Common Yellowthroat
# 69   obsr95380       2022-11-25       Boat-tailed Grackle
# 70   obsr95380       2022-11-25      Northern Mockingbird
# 71   obsr95380       2022-11-25     Yellow-rumped Warbler
# 72   obsr95380       2022-11-25       Common Yellowthroat
# 73   obsr95380       2022-11-25                House Wren
# 74   obsr95380       2022-11-25             Mourning Dove
# 75   obsr95380       2022-11-25       Red-shouldered Hawk
# 76   obsr95380       2022-11-25            Eastern Phoebe
# 77   obsr95380       2022-11-25     Blue-gray Gnatcatcher
# 78   obsr95380       2022-11-25                 Fish Crow
# 79   obsr95380       2022-11-25          American Kestrel
# 80   obsr95380       2022-11-25                  Blue Jay
# 81   obsr95380       2022-11-25    Red-bellied Woodpecker
# 82   obsr95380       2022-11-25            Common Grackle
# 83   obsr95380       2022-11-25              Gray Catbird
# 84   obsr95380       2022-11-25              Palm Warbler
# 85   obsr95380       2022-11-25             American Crow
# 86   obsr95380       2022-11-25         Northern Cardinal
# 87   obsr95380       2022-11-25                  Killdeer
# 88   obsr95380       2022-11-25    Eurasian Collared-Dove
#
#              SCIENTIFIC_NAME  DURATION_MINUTES OBSERVATION_COUNT  \
# 0      Cardinalis cardinalis             188.0                 5
# 1        Seiurus aurocapilla             188.0                 2
# 2        Cyanocitta cristata             188.0                 5
# 3            Sayornis phoebe             188.0                 2
# 4   Haliaeetus leucocephalus             188.0                 1
# 5          Troglodytes aedon             188.0                16
# 6         Spizella passerina             188.0                27
# 7              Vireo griseus             188.0                 2
# 8         Baeolophus bicolor             188.0                 2
# 9        Meleagris gallopavo             188.0                 1
# 10       Polioptila caerulea             188.0                16
# 11           Quiscalus major             188.0                 2
# 12       Butorides virescens             188.0                 1
# 13           Sturnella magna             188.0                 2
# 14          Vireo solitarius             188.0                 1
# 15       Antigone canadensis             188.0                 1
# 16        Setophaga coronata             188.0                21
# 17       Dryobates pubescens             188.0                 1
# 18        Setophaga dominica             188.0                 2
# 19        Setophaga coronata             188.0                11
# 20         Mimus polyglottos             188.0                 4
# 21        Dryocopus pileatus             188.0                 1
# 22                Ardea alba             188.0                 1
# 23      Melanerpes carolinus             188.0                 3
# 24          Colaptes auratus             188.0                 1
# 25    Dumetella carolinensis             188.0                 9
# 26        Setophaga palmarum             188.0                 1
# 27         Corvus ossifragus             188.0                 1
# 28        Mycteria americana             188.0                 1
# 29        Quiscalus quiscula             188.0                 1
# 30        Geothlypis trichas             188.0                 3
# 31       Corthylio calendula             188.0                 1
# 32      Charadrius vociferus             188.0                 1
# 33        Turdus migratorius             188.0                 3
# 34          Coragyps atratus             188.0                12
# 35       Columbina passerina             188.0                 1
# 36           Mniotilta varia             188.0                 1
# 37            Buteo lineatus             188.0                 2
# 38     Corvus brachyrhynchos             188.0                 2
# 39        Setophaga palmarum             188.0                12
# 40          Egretta caerulea             188.0                 1
# 41           Setophaga pinus             188.0                20
# 42       Setophaga ruticilla             188.0                 1
# 43        Setophaga palmarum             188.0                12
# 44          Zenaida macroura             188.0                18
# 45        Sphyrapicus varius             188.0                 1
# 46       Lanius ludovicianus             188.0                 1
# 47            Cathartes aura             188.0                 2
# 48             Vireo griseus              24.0                 2
# 49        Turdus migratorius              24.0                 3
# 50       Setophaga ruticilla              24.0                 1
# 51      Melanerpes carolinus              24.0                 2
# 52        Setophaga coronata              24.0                17
# 53         Catharus guttatus              24.0                 1
# 54       Antigone canadensis              24.0                 2
# 55           Mniotilta varia              24.0                 1
# 56         Troglodytes aedon              24.0                 1
# 57        Setophaga discolor              24.0                 2
# 58       Dryobates pubescens              24.0                 1
# 59    Dumetella carolinensis              24.0                 6
# 60       Seiurus aurocapilla              24.0                 2
# 61           Sayornis phoebe              24.0                 2
# 62        Setophaga dominica              24.0                 1
# 63  Thryothorus ludovicianus              24.0                 2
# 64       Polioptila caerulea              24.0                11
# 65       Cyanocitta cristata              24.0                 2
# 66          Vireo solitarius              24.0                 2
# 67     Cardinalis cardinalis              24.0                 4
# 68        Geothlypis trichas              24.0                 2
# 69           Quiscalus major              13.0                 2
# 70         Mimus polyglottos              13.0                 3
# 71        Setophaga coronata              13.0                 4
# 72        Geothlypis trichas              13.0                 1
# 73         Troglodytes aedon              13.0                 1
# 74          Zenaida macroura              13.0                 7
# 75            Buteo lineatus              13.0                 1
# 76           Sayornis phoebe              13.0                 1
# 77       Polioptila caerulea              13.0                 2
# 78         Corvus ossifragus              13.0                 1
# 79          Falco sparverius              13.0                 1
# 80       Cyanocitta cristata              13.0                 2
# 81      Melanerpes carolinus              13.0                 1
# 82        Quiscalus quiscula              13.0                15
# 83    Dumetella carolinensis              13.0                 5
# 84        Setophaga palmarum              13.0                 2
# 85     Corvus brachyrhynchos              13.0                 5
# 86     Cardinalis cardinalis              13.0                 1
# 87      Charadrius vociferus              13.0                 1
# 88     Streptopelia decaocto              13.0                 2
#
#    TIME_OBSERVATIONS_STARTED SAMPLING_EVENT_IDENTIFIER PROTOCOL_TYPE  \
# 0                   08:18:00                S122984520     Traveling
# 1                   08:18:00                S122984520     Traveling
# 2                   08:18:00                S122984520     Traveling
# 3                   08:18:00                S122984520     Traveling
# 4                   08:18:00                S122984520     Traveling
# 5                   08:18:00                S122984520     Traveling
# 6                   08:18:00                S122984520     Traveling
# 7                   08:18:00                S122984520     Traveling
# 8                   08:18:00                S122984520     Traveling
# 9                   08:18:00                S122984520     Traveling
# 10                  08:18:00                S122984520     Traveling
# 11                  08:18:00                S122984520     Traveling
# 12                  08:18:00                S122984520     Traveling
# 13                  08:18:00                S122984520     Traveling
# 14                  08:18:00                S122984520     Traveling
# 15                  08:18:00                S122984520     Traveling
# 16                  08:18:00                S122984520     Traveling
# 17                  08:18:00                S122984520     Traveling
# 18                  08:18:00                S122984520     Traveling
# 19                  08:18:00                S122984520     Traveling
# 20                  08:18:00                S122984520     Traveling
# 21                  08:18:00                S122984520     Traveling
# 22                  08:18:00                S122984520     Traveling
# 23                  08:18:00                S122984520     Traveling
# 24                  08:18:00                S122984520     Traveling
# 25                  08:18:00                S122984520     Traveling
# 26                  08:18:00                S122984520     Traveling
# 27                  08:18:00                S122984520     Traveling
# 28                  08:18:00                S122984520     Traveling
# 29                  08:18:00                S122984520     Traveling
# 30                  08:18:00                S122984520     Traveling
# 31                  08:18:00                S122984520     Traveling
# 32                  08:18:00                S122984520     Traveling
# 33                  08:18:00                S122984520     Traveling
# 34                  08:18:00                S122984520     Traveling
# 35                  08:18:00                S122984520     Traveling
# 36                  08:18:00                S122984520     Traveling
# 37                  08:18:00                S122984520     Traveling
# 38                  08:18:00                S122984520     Traveling
# 39                  08:18:00                S122984520     Traveling
# 40                  08:18:00                S122984520     Traveling
# 41                  08:18:00                S122984520     Traveling
# 42                  08:18:00                S122984520     Traveling
# 43                  08:18:00                S122984520     Traveling
# 44                  08:18:00                S122984520     Traveling
# 45                  08:18:00                S122984520     Traveling
# 46                  08:18:00                S122984520     Traveling
# 47                  08:18:00                S122984520     Traveling
# 48                  07:40:00                S122974477     Traveling
# 49                  07:40:00                S122974477     Traveling
# 50                  07:40:00                S122974477     Traveling
# 51                  07:40:00                S122974477     Traveling
# 52                  07:40:00                S122974477     Traveling
# 53                  07:40:00                S122974477     Traveling
# 54                  07:40:00                S122974477     Traveling
# 55                  07:40:00                S122974477     Traveling
# 56                  07:40:00                S122974477     Traveling
# 57                  07:40:00                S122974477     Traveling
# 58                  07:40:00                S122974477     Traveling
# 59                  07:40:00                S122974477     Traveling
# 60                  07:40:00                S122974477     Traveling
# 61                  07:40:00                S122974477     Traveling
# 62                  07:40:00                S122974477     Traveling
# 63                  07:40:00                S122974477     Traveling
# 64                  07:40:00                S122974477     Traveling
# 65                  07:40:00                S122974477     Traveling
# 66                  07:40:00                S122974477     Traveling
# 67                  07:40:00                S122974477     Traveling
# 68                  07:40:00                S122974477     Traveling
# 69                  07:23:00                S122973107     Traveling
# 70                  07:23:00                S122973107     Traveling
# 71                  07:23:00                S122973107     Traveling
# 72                  07:23:00                S122973107     Traveling
# 73                  07:23:00                S122973107     Traveling
# 74                  07:23:00                S122973107     Traveling
# 75                  07:23:00                S122973107     Traveling
# 76                  07:23:00                S122973107     Traveling
# 77                  07:23:00                S122973107     Traveling
# 78                  07:23:00                S122973107     Traveling
# 79                  07:23:00                S122973107     Traveling
# 80                  07:23:00                S122973107     Traveling
# 81                  07:23:00                S122973107     Traveling
# 82                  07:23:00                S122973107     Traveling
# 83                  07:23:00                S122973107     Traveling
# 84                  07:23:00                S122973107     Traveling
# 85                  07:23:00                S122973107     Traveling
# 86                  07:23:00                S122973107     Traveling
# 87                  07:23:00                S122973107     Traveling
# 88                  07:23:00                S122973107     Traveling
#
#    PROTOCOL_CODE
# 0            P22
# 1            P22
# 2            P22
# 3            P22
# 4            P22
# 5            P22
# 6            P22
# 7            P22
# 8            P22
# 9            P22
# 10           P22
# 11           P22
# 12           P22
# 13           P22
# 14           P22
# 15           P22
# 16           P22
# 17           P22
# 18           P22
# 19           P22
# 20           P22
# 21           P22
# 22           P22
# 23           P22
# 24           P22
# 25           P22
# 26           P22
# 27           P22
# 28           P22
# 29           P22
# 30           P22
# 31           P22
# 32           P22
# 33           P22
# 34           P22
# 35           P22
# 36           P22
# 37           P22
# 38           P22
# 39           P22
# 40           P22
# 41           P22
# 42           P22
# 43           P22
# 44           P22
# 45           P22
# 46           P22
# 47           P22
# 48           P22
# 49           P22
# 50           P22
# 51           P22
# 52           P22
# 53           P22
# 54           P22
# 55           P22
# 56           P22
# 57           P22
# 58           P22
# 59           P22
# 60           P22
# 61           P22
# 62           P22
# 63           P22
# 64           P22
# 65           P22
# 66           P22
# 67           P22
# 68           P22
# 69           P22
# 70           P22
# 71           P22
# 72           P22
# 73           P22
# 74           P22
# 75           P22
# 76           P22
# 77           P22
# 78           P22
# 79           P22
# 80           P22
# 81           P22
# 82           P22
# 83           P22
# 84           P22
# 85           P22
# 86           P22
# 87           P22
# 88           P22

# %%
sql = """
WITH distinct_observation_minutes AS
(
    SELECT
            observer_id,
            observation_date,
            time_observations_started,
            COALESCE(MAX(duration_minutes), 1) as observation_minutes
    FROM read_parquet(
        ['data/ebird_2015.parquet',
        'data/ebird_2016.parquet',
        'data/ebird_2017.parquet',
        'data/ebird_2018.parquet',
        'data/ebird_2019.parquet',
        'data/ebird_2020.parquet',
        'data/ebird_2021.parquet',
        'data/ebird_2022.parquet'])
    GROUP BY 1,2,3
)

SELECT
    make_date(extract('year' FROM CAST(observation_date AS date)), extract('month' FROM CAST(observation_date AS date)), 1) AS observation_month,
    sum(observation_minutes) as total_observation_minutes
FROM distinct_observation_minutes
GROUP BY 1
"""
results = duckdb.sql(sql)
duration_df = results.df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
duration_df = duration_df.sort_values(by='observation_month')
duration_df['total_observation_hours'] = duration_df['total_observation_minutes'] / 60
duration_df['millions_observation_hours'] = duration_df['total_observation_minutes'] / 60 / 1000000

# %%
import matplotlib.dates as mdates
myFmt = mdates.DateFormatter('%Y-%m')
fmt_month = mdates.MonthLocator()

fig, ax = plt.subplots()
ax.plot(duration_df['observation_month'], duration_df['millions_observation_hours'], label="Monthly Observation Hours")
ax.set_ylim(0, 1.4)
ax.set_ylabel("Millions of Hours")
ax.set_title("Monthly Hours Logged Observating (USA States)")
ax.xaxis.set_major_formatter(myFmt)
ax.xaxis.set_minor_locator(fmt_month)
fig.autofmt_xdate()
